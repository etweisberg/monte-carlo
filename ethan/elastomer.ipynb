# %%
import numpy as n
import matplotlib.pyplot as plt
import math

# %%
n_steps = 100000
path = np.random.randint(0,2,n_steps)
path[path==0] = -1

# %%
lengths = np.cumsum(path)

# %%
plt.xlabel('N')
plt.ylabel('distance')
plt.plot(lengths)

# %%
# Testing out P(R) = exp(-3R^2/2Nb^2)

def gen_polymer():
    end_to_ends = []

    for i in range(1000):
        n_steps = 1000
        path = np.random.randint(0,2,n_steps)
        path[path==0] = -1
        square_end_to_end = np.sum(path)**2
        end_to_ends.append(square_end_to_end)
    return np.average(end_to_ends)

# %%
R_values = []
for i in range(1000):
    R_values.append(math.sqrt(gen_polymer()))
plt.plot(R_values)
